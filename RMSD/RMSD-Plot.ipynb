# %% [markdown]
# #### RMSD Plotting

# %% [markdown]
# This is a Jupyter Notebook for RMSD visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import statistics

# %%
#rcParams['figure.figsize'] = 10, 7
rcParams.update({'font.size': 15})

# %%
rmsd = np.loadtxt('trajrmsd.dat')
time = rmsd[:, 0] * 0.004 #use the timestep from your MD simulations

# %%
# Create Fig and gridspec
fig = plt.figure(figsize=(10, 5), dpi= 100)
grid = plt.GridSpec(4, 4, hspace=0.5, wspace=0.2)

# Define the axes
ax_main = fig.add_subplot(grid[:-1, :-1])
ax_right = fig.add_subplot(grid[:-1, -1], yticklabels=[])

# Lineplot on main ax
ax_main.plot(time, rmsd[:,1], '#1E90FF', label='Molecule A')

ax_right.hist(rmsd[:,1], bins=100, range=[0, 10], histtype='stepfilled', orientation='horizontal', alpha = 0.4, color ='#1E90FF', edgecolor ='#1E90FF', linewidth=2)

ax_main.set_xlim([0, 100])
ax_main.set_ylim([0, 10])

ax_right.set_xlim([0, 2000])
ax_right.set_ylim([0, 10])
ax_right.set_xlabel('Count')
#ax_right.set_ylabel('RMSD ($\AA$)')

ax_main.set_xlabel('Time (ns)')
ax_main.set_ylabel('RMSD ($\AA$)')
ax_main.legend()

#fig.savefig('RMSD.png', dpi=300)

# %%
statistics.mean(rmsd[:,1])
# Out:
# 5.787288788448462

# %%
statistics.stdev(rmsd[:,1])
# Out:
# 0.9199575084741122
